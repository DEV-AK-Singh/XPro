# %% [markdown]
# # MATPLOTLIB

# %% [markdown]
# ## 1. BAR PLOT

# %%
import matplotlib.pyplot as plt
x = ["java", "python", "C++"]
y2025 = [70, 90, 80]
y2026 = [80, 70, 90]
plt.title("Languages popularites")
plt.xlabel("Languages")
plt.ylabel("Popularty")
plt.bar(x, y2025, width=0.3, color="y", align="center", edgecolor="b", linewidth=2, linestyle=":", label="wscube")
plt.bar(x, y2026, width=0.3, color="y", align="center", edgecolor="b", linewidth=2, linestyle=":", label="wscube")
plt.legend()
plt.show()
